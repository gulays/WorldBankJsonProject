# %% [markdown]
# # JSON examples and exercise
# ****
# + get familiar with packages for dealing with JSON
# + study examples with JSON strings and files
# + work on exercise to be completed and submitted
# ****
# + reference: http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader
# + data source: http://jsonstudio.com/resources/
# ****

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## imports for Python, Pandas

# %%
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## JSON example, with string
#
# + demonstrates creation of normalized dataframes (tables) from nested json string
# + source: http://pandas.pydata.org/pandas-docs/stable/io.html#normalization

# %%
# define json string
data = [{'state': 'Florida', 
         'shortname': 'FL',
         'info': {'governor': 'Rick Scott'},
         'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
        {'state': 'Ohio',
         'shortname': 'OH',
         'info': {'governor': 'John Kasich'},
         'counties': [{'name': 'Summit', 'population': 1234},
                      {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
# use normalization to create tables from nested element
json_normalize(data, 'counties')
# Out:
#          name  population
# 0        Dade       12345
# 1     Broward       40000
# 2  Palm Beach       60000
# 3      Summit        1234
# 4    Cuyahoga        1337

# %%
# further populate tables created from nested element
json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# ****
# ## JSON example, with file
#
# + demonstrates reading in a json file as a string and as a table
# + uses small sample file containing data about projects funded by the World Bank
# + data source: http://jsonstudio.com/resources/

# %%
# load json as string
json.load((open('data/world_bank_projects_less.json')))
# Out:
# [{'_id': {'$oid': '52b213b38594d8a2be17c780'},
#   'approvalfy': 1999,
#   'board_approval_month': 'November',
#   'boardapprovaldate': '2013-11-12T00:00:00Z',
#   'borrower': 'FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA',
#   'closingdate': '2018-07-07T00:00:00Z',
#   'country_namecode': 'Federal Democratic Republic of Ethiopia!$!ET',
#   'countrycode': 'ET',
#   'countryname': 'Federal Democratic Republic of Ethiopia',
#   'countryshortname': 'Ethiopia',
#   'docty': 'Project Information Document,Indigenous Peoples Plan,Project Information Document',
#   'envassesmentcategorycode': 'C',
#   'grantamt': 0,
#   'ibrdcommamt': 0,
#   'id': 'P129828',
#   'idacommamt': 130000000,
#   'impagency': 'MINISTRY OF EDUCATION',
#   'lendinginstr': 'Investment Project Financing',
#   'lendinginstrtype': 'IN',
#   'lendprojectcost': 550000000,
#   'majorsector_percent': [{'Name': 'Education', 'Percent': 46},
#    {'Name': 'Education', 'Percent': 26},
# ...

# %%
# load as Pandas dataframe
WB = pd.read_json('data/world_bank_projects.json')
WB.head(10)
# Out:
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2  {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3  {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4  {'$oid': '52b213b38594d8a2be17c784'}        2014              October
# 5  {'$oid': '52b213b38594d8a2be17c785'}        2014              October
# 6  {'$oid': '52b213b38594d8a2be17c786'}        2014              October
# 7  {'$oid': '52b213b38594d8a2be17c787'}        2014              October
# 8  {'$oid': '52b213b38594d8a2be17c788'}        2014              October
# 9  {'$oid': '52b213b38594d8a2be17c789'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# ...

# %% [markdown]
# ****
# ## JSON exercise
#
# Using data in file 'data/world_bank_projects.json' and the techniques demonstrated above,
# 1. Find the 10 countries with most projects
# 2. Find the top 10 major project themes (using column 'mjtheme_namecode')
# 3. In 2. above you will notice that some entries have only the code and the name is missing. Create a dataframe with the missing names filled in.

# %%
WB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 50 columns):
# _id                         500 non-null object
# approvalfy                  500 non-null int64
# board_approval_month        500 non-null object
# boardapprovaldate           500 non-null object
# borrower                    485 non-null object
# closingdate                 370 non-null object
# country_namecode            500 non-null object
# countrycode                 500 non-null object
# countryname                 500 non-null object
# countryshortname            500 non-null object
# docty                       446 non-null object
# envassesmentcategorycode    430 non-null object
# grantamt                    500 non-null int64
# ibrdcommamt                 500 non-null int64
# id                          500 non-null object
# idacommamt                  500 non-null int64
# impagency                   472 non-null object
# ...

# %%
#Find the 10 countries with most projects
#countryname column has no nan values!
WB.groupby('countryname').count()['_id'].sort_values(ascending = False).head(10)
# Out:
# countryname
# People's Republic of China         19
# Republic of Indonesia              19
# Socialist Republic of Vietnam      17
# Republic of India                  16
# Republic of Yemen                  13
# Nepal                              12
# People's Republic of Bangladesh    12
# Kingdom of Morocco                 12
# Africa                             11
# Republic of Mozambique             11
# Name: _id, dtype: int64

# %%
data = json.load((open('data/world_bank_projects.json')))
json_n = json_normalize(data, 'mjtheme_namecode',['id','countryname'])
json_n
top10code = json_n.code.value_counts().head(10)
top10code
# Out:
# 11    250
# 10    216
# 8     210
# 2     199
# 6     168
# 4     146
# 7     130
# 5      77
# 9      50
# 1      38
# Name: code, dtype: int64

# %%
#Find the top 10 major project themes (using column 'mjtheme_namecode')

# %%
WB = json.load((open('data/world_bank_projects.json')))

# %%
WB_theme = json_normalize(WB, 'mjtheme_namecode',['id','countryname']).sort_values(by='code')

# %%
#a = WB_theme[WB_theme.name == ''] 
#len(a)

#b = WB_theme[WB_theme.name != '']
#len(b)
# Out:
# 1377

# %%
#WB_theme['name'] = WB_theme['name'].replace('', 'NaN')
#WB_theme['name'] = WB_theme['name'].replace('NaN', method='ffill')

WB_theme['name'] = WB_theme['name'].replace('', method='ffill')
WB_theme
# Out:
#      code                 name       id  \
# 458     1  Economic management  P130925
# 1235    1  Economic management  P131440
# 1230    1  Economic management  P129465
# 1229    1  Economic management  P129465
# 1218    1  Economic management  P130824
# 900     1  Economic management  P143819
# 648     1  Economic management  P129825
# 647     1  Economic management  P129825
# 1078    1  Economic management  P131234
# 1206    1  Economic management  P133255
# 1437    1  Economic management  P130412
# 357     1  Economic management  P130459
# 363     1  Economic management  P144030
# 1010    1  Economic management  P133706
# 784     1  Economic management  P110836
# 1024    1  Economic management  P124114
# 88      1  Economic management  P132425
# 1045    1  Economic management  P133791
# 497     1  Economic management  P133663
# 1056    1  Economic management  P144633
# 1057    1  Economic management  P144633
# 1114    1  Economic management  P131094
# ...

# %%
WB_theme.groupby(['code','name']).size().sort_values(ascending=False)
# Out:
# code  name
# 11    Environment and natural resources management    250
# 10    Rural development                               216
# 8     Human development                               210
# 2     Public sector governance                        199
# 6     Social protection and risk management           168
# 4     Financial and private sector development        146
# 7     Social dev/gender/inclusion                     130
# 5     Trade and integration                            77
# 9     Urban development                                50
# 1     Economic management                              38
# 3     Rule of law                                      15
# dtype: int64

# %%
#a = a[a.name == np.NaN]
a['name'] = 'NaN'
a
# Out:
# C:\Users\gulay\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#      code name       id                               countryname
# 1437    1  NaN  P130412                     Republic of Guatemala
# 363     1  NaN  P144030                 Republic of Cote d'Ivoire
# 1024    1  NaN  P124114               United Republic of Tanzania
# 1114    1  NaN  P131094                      Republic of Honduras
# 212     1  NaN  P128282                       Republic of Liberia
# 217    10  NaN  P132920                           Kyrgyz Republic
# 391    10  NaN  P145311                       Republic of Vanuatu
# ...

# %%
WB_theme[WB_theme[0]==""] = np.NaN
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\gulay\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
WB_theme.name
# Out:
# 458     Economic management
# 1235    Economic management
# 1230    Economic management
# 1229    Economic management
# 1218    Economic management
# 900     Economic management
# 648     Economic management
# 647     Economic management
# 1078    Economic management
# 1206    Economic management
# 1437
# 357     Economic management
# 363
# 1010    Economic management
# 784     Economic management
# 1024
# 88      Economic management
# 1045    Economic management
# 497     Economic management
# 1056    Economic management
# 1057    Economic management
# 1114
# 454     Economic management
# 453     Economic management
# 1257    Economic management
# 1260    Economic management
# 1212    Economic management
# 249     Economic management
# 841     Economic management
# 220     Economic management
#                ...
# 669       Urban development
# 1303      Urban development
# 1347      Urban development
# 460
# 1342      Urban development
# 183       Urban development
# ...

# %%
WB_theme.name.isnull().value_counts()
# Out:
# False    1499
# Name: name, dtype: int64

# %%
WB_theme.name.replace('',method='ffill')
#WB2
# Out:
# 458     Economic management
# 1235    Economic management
# 1230    Economic management
# 1229    Economic management
# 1218    Economic management
# 900     Economic management
# 648     Economic management
# 647     Economic management
# 1078    Economic management
# 1206    Economic management
# 1437    Economic management
# 357     Economic management
# 363     Economic management
# 1010    Economic management
# 784     Economic management
# 1024    Economic management
# 88      Economic management
# 1045    Economic management
# 497     Economic management
# 1056    Economic management
# 1057    Economic management
# 1114    Economic management
# 454     Economic management
# 453     Economic management
# 1257    Economic management
# 1260    Economic management
# 1212    Economic management
# 249     Economic management
# 841     Economic management
# 220     Economic management
#                ...
# 669       Urban development
# 1303      Urban development
# ...

# %%
WB2.groupby('name').size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-7ff74b51b662> in <module>()
# ----> 1 WB2.groupby('name').size()
#
# C:\Users\gulay\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3989         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3990                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3991                        **kwargs)
# ...

# %%
tata = json_normalize(WB, 'mjtheme_namecode',['id','countryname']).sort_values(by='code',ascending = False)

# %%
tata
# Out:
#      code                 name       id  \
# 1103    9    Urban development  P130972
# 650     9    Urban development  P123384
# 369     9    Urban development  P126749
# 1095    9    Urban development  P130819
# 585     9    Urban development  P123729
# 597     9    Urban development  P129713
# 598     9    Urban development  P129713
# 1318    9    Urban development  P130461
# 356     9    Urban development  P127543
# 1102    9    Urban development  P130972
# 1104    9    Urban development  P130972
# 53      9    Urban development  P145359
# 341     9    Urban development  P144357
# 333     9                       P132154
# 1303    9    Urban development  P130528
# 320     9    Urban development  P122950
# 318     9    Urban development  P122950
# 822     9    Urban development  P125022
# 570     9    Urban development  P119039
# 1428    9    Urban development  P118916
# 962     9    Urban development  P132268
# 940     9    Urban development  P127955
# ...

# %%
#tatat['name'] = tata.name.replace('', method='bfill')

# %%
tatat
# Out:
# 1103                                    Urban development
# 650                                     Urban development
# 369                                     Urban development
# 1095                                    Urban development
# 585                                     Urban development
# 597                                     Urban development
# 598                                     Urban development
# 1318                                    Urban development
# 356                                     Urban development
# 1102                                    Urban development
# 1104                                    Urban development
# 53                                      Urban development
# 341                                     Urban development
# 333                                     Urban development
# 1303                                    Urban development
# 320                                     Urban development
# ...
